# %%
# !pip install faker

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
import io


employees = pd.read_csv(io.BytesIO(uploaded['old_employees.csv']))
print(employees.head())
# Out:
#      <input type="file" id="files-e8aab211-cb7c-4f30-81f7-615ce9c9319f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e8aab211-cb7c-4f30-81f7-615ce9c9319f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from datetime import date
fake = Faker()


def generate_unique_employee_data(num_records):
    data = []
    departments = ['Legal', 'Marketing', 'Administrative', 'Operations', 'Sales', 'Finance', 'I/T', 'Product', 'Human Resource']
    department_weights = [0.05, 0.1, 0.1, 0.2, 0.1, 0.05, 0.1, 0.2, 0.1]

    for employee_id in range(1, num_records + 1):
        gender = random.choice(['Male', 'Female'])
        citizenship = random.choices(
            ['USA', 'India', 'China', 'Canada', 'South Korea', 'Philippines', 'Taiwan', 'Mexico'],
            weights=[0.6, 0.16, 0.11, 0.05, 0.03, 0.025, 0.015, 0.01],
            k=1
        )[0]
        languages_spoken = ', '.join(fake.words(nb=random.randint(0, 2), ext_word_list=['Spanish', 'French', 'Mandarin', 'Hindi', 'Arabic'])) or 'None'
        department = random.choices(departments, weights=department_weights, k=1)[0]
        salary = round(random.uniform(40000, 160000), 2)
        ssn = fake.ssn()
        birth_year = random.randint(1955, 2000)
        current_year = date.today().year
        age = current_year - birth_year
        years_experience = max(0, age - random.randint(18, 22))

        data.append({
            'EmployeeID': employee_id,
            'FullName': fake.name(),
            'Gender': gender,
            'Citizenship': citizenship,
            'LanguagesSpoken': languages_spoken,
            'Department': department,
            'AnnualSalary': salary,
            'SocialSecurityNumber': ssn,
            'Age': age,
            'YearsOfExperience': years_experience
        })

    return pd.DataFrame(data)

# Generate synthetic data
synthetic_data_unique = generate_unique_employee_data(10000)

# Save to CSV
synthetic_data_unique.to_csv('database.csv', index=False)

print("Unique synthetic dataset created and saved to 'database.csv'")

# Download the generated CSV file
from google.colab import files
files.download('database.csv')
# Out:
# Unique synthetic dataset created and saved to 'database.csv'
